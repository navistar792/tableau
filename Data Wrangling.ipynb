# %%
import pandas as pd
import glob

# %%
# path = r'C:/Users/rvern/Documents/GitHub/tableau' # use your path
# all_files = glob.glob(path + "/*.csv")

# li = []

# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)

# frame = pd.concat(li, axis=0, ignore_index=True)

# %%
# frame
# Out:
#         tripduration                 starttime                  stoptime  \
# 0             1553.0  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1              416.0  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2              294.0  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3               97.0  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4              286.0  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
# ...              ...                       ...                       ...
# 892799           NaN                       NaN                       NaN
# 892800           NaN                       NaN                       NaN
# 892801           NaN                       NaN                       NaN
# 892802           NaN                       NaN                       NaN
# 892803           NaN                       NaN                       NaN
#
#         start station id start station name  start station latitude  \
# ...

# %%
# # Export file as a CSV, without the Pandas index, but with the header
# frame.to_csv("fileOne.csv", index=False, header=True)

# %%
file1 = "C:/Users/rvern/Documents/GitHub/tableau/citibike-tripdata_oldformat.csv"
df1 = pd.read_csv(file1)
df1
# Out:
#         tripduration      starttime       stoptime  start station id  \
# 0               1553   12/1/19 0:07   12/1/19 0:33              3681
# 1                416   12/1/19 0:16   12/1/19 0:23              3195
# 2                294   12/1/19 0:20   12/1/19 0:25              3195
# 3                 97   12/1/19 0:21   12/1/19 0:22              3202
# 4                286   12/1/19 0:29   12/1/19 0:34              3195
# ...              ...            ...            ...               ...
# 354698          2476  1/31/21 20:16  1/31/21 20:57              3187
# 354699           147  1/31/21 21:05  1/31/21 21:07              3186
# 354700           660  1/31/21 21:06  1/31/21 21:17              3211
# 354701           384  1/31/21 21:16  1/31/21 21:23              3205
# 354702           356  1/31/21 23:24  1/31/21 23:30              3639
#
#        start station name  start station latitude  start station longitude  \
# ...

# %%
df1.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'Unnamed: 15'],
#       dtype='object')

# %%
df1 = df1.drop(columns=['birth year', 'gender','bikeid','Unnamed: 15'])
df1
# Out:
#         tripduration      starttime       stoptime  start station id  \
# 0               1553   12/1/19 0:07   12/1/19 0:33              3681
# 1                416   12/1/19 0:16   12/1/19 0:23              3195
# 2                294   12/1/19 0:20   12/1/19 0:25              3195
# 3                 97   12/1/19 0:21   12/1/19 0:22              3202
# 4                286   12/1/19 0:29   12/1/19 0:34              3195
# ...              ...            ...            ...               ...
# 354698          2476  1/31/21 20:16  1/31/21 20:57              3187
# 354699           147  1/31/21 21:05  1/31/21 21:07              3186
# 354700           660  1/31/21 21:06  1/31/21 21:17              3211
# 354701           384  1/31/21 21:16  1/31/21 21:23              3205
# 354702           356  1/31/21 23:24  1/31/21 23:30              3639
#
#        start station name  start station latitude  start station longitude  \
# ...

# %%
df1.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'usertype'],
#       dtype='object')

# %%
df1['starttime'] = pd.to_datetime(df1['starttime'])
df1['stoptime'] = pd.to_datetime(df1['stoptime'])
df1
# Out:
#         tripduration           starttime            stoptime  \
# 0               1553 2019-12-01 00:07:00 2019-12-01 00:33:00
# 1                416 2019-12-01 00:16:00 2019-12-01 00:23:00
# 2                294 2019-12-01 00:20:00 2019-12-01 00:25:00
# 3                 97 2019-12-01 00:21:00 2019-12-01 00:22:00
# 4                286 2019-12-01 00:29:00 2019-12-01 00:34:00
# ...              ...                 ...                 ...
# 354698          2476 2021-01-31 20:16:00 2021-01-31 20:57:00
# 354699           147 2021-01-31 21:05:00 2021-01-31 21:07:00
# 354700           660 2021-01-31 21:06:00 2021-01-31 21:17:00
# 354701           384 2021-01-31 21:16:00 2021-01-31 21:23:00
# 354702           356 2021-01-31 23:24:00 2021-01-31 23:30:00
#
#         start station id start station name  start station latitude  \
# 0                   3681           Grand St               40.715178
# 1                   3195            Sip Ave               40.730897
# ...

# %%
df1
# Out:
#         tripduration           starttime            stoptime  \
# 0               1553 2019-12-01 00:07:00 2019-12-01 00:33:00
# 1                416 2019-12-01 00:16:00 2019-12-01 00:23:00
# 2                294 2019-12-01 00:20:00 2019-12-01 00:25:00
# 3                 97 2019-12-01 00:21:00 2019-12-01 00:22:00
# 4                286 2019-12-01 00:29:00 2019-12-01 00:34:00
# ...              ...                 ...                 ...
# 354698          2476 2021-01-31 20:16:00 2021-01-31 20:57:00
# 354699           147 2021-01-31 21:05:00 2021-01-31 21:07:00
# 354700           660 2021-01-31 21:06:00 2021-01-31 21:17:00
# 354701           384 2021-01-31 21:16:00 2021-01-31 21:23:00
# 354702           356 2021-01-31 23:24:00 2021-01-31 23:30:00
#
#         start station id start station name  start station latitude  \
# 0                   3681           Grand St               40.715178
# 1                   3195            Sip Ave               40.730897
# ...

# %%
## second dataframe

# %%
file2 = "C:/Users/rvern/Documents/GitHub/tableau/citibike-tripdata_newformat.csv"
df2 = pd.read_csv(file2)
df2
# Out:
#                  ride_id rideable_type        started_at          ended_at  \
# 0       62F2D98DDA10BFFF   docked_bike       2/1/21 0:42       2/1/21 0:52
# 1       FA2789B14DB04DED   docked_bike       2/1/21 6:29       2/1/21 6:37
# 2       1194EA4A3DE71713   docked_bike      2/3/21 12:27      2/3/21 12:59
# 3       E424C4CFD509FB95   docked_bike      2/3/21 12:42      2/3/21 12:57
# 4       341691DED03AD770   docked_bike      2/3/21 13:26      2/3/21 13:31
# ...                  ...           ...               ...               ...
# 524645  ED27762E6E429228  classic_bike  10/31/2021 23:47    11/1/2021 0:49
# 524646  241879350D5776CB  classic_bike  10/31/2021 23:54  10/31/2021 23:59
# 524647  38F550DF924E5E0A  classic_bike  10/31/2021 23:59    11/1/2021 0:28
# 524648  DE182CF27D0CCFBD  classic_bike  10/31/2021 23:59    11/1/2021 0:11
# 524649  F64A02EE36E86846  classic_bike  10/31/2021 23:59    11/1/2021 0:29
#
# ...

# %%
df2['started_at'] = pd.to_datetime(df2['started_at'])
df2['ended_at'] = pd.to_datetime(df2['ended_at'])
df2.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
df2["tripduration"] = (df2['ended_at']-df2['started_at']).astype('timedelta64[s]')

# %%
df2.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'tripduration'],
#       dtype='object')

# %%
df2 = df2.drop(columns=['ride_id', 'rideable_type'])
df2
# Out:
#                 started_at            ended_at  \
# 0      2021-02-01 00:42:00 2021-02-01 00:52:00
# 1      2021-02-01 06:29:00 2021-02-01 06:37:00
# 2      2021-02-03 12:27:00 2021-02-03 12:59:00
# 3      2021-02-03 12:42:00 2021-02-03 12:57:00
# 4      2021-02-03 13:26:00 2021-02-03 13:31:00
# ...                    ...                 ...
# 524645 2021-10-31 23:47:00 2021-11-01 00:49:00
# 524646 2021-10-31 23:54:00 2021-10-31 23:59:00
# 524647 2021-10-31 23:59:00 2021-11-01 00:28:00
# 524648 2021-10-31 23:59:00 2021-11-01 00:11:00
# 524649 2021-10-31 23:59:00 2021-11-01 00:29:00
#
#                       start_station_name start_station_id   end_station_name  \
# 0                              City Hall            JC003    Brunswick & 6th
# 1                             Bergen Ave            JC095            Sip Ave
# 2                             Newark Ave            JC032       Morris Canal
# 3                           Morris Canal            JC072       Newport Pkwy
# ...

# %%
df2.columns
# Out:
# Index(['started_at', 'ended_at', 'start_station_name', 'start_station_id',
#        'end_station_name', 'end_station_id', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng', 'member_casual', 'tripduration'],
#       dtype='object')

# %%
df2 = df2.rename(columns={'started_at':'starttime', 'ended_at': 'stoptime', 'start_station_name':'start station name', 'start_station_id':'start station id','end_station_name':'end station name', 'end_station_id':'end station id', 'start_lat':'start station latitude', 'start_lng':'start station longitude','end_lat':'end station latitude', 'end_lng':'end station longitude', 'member_casual':'usertype'}, errors="raise")

# %%
df2
# Out:
#                  starttime            stoptime  \
# 0      2021-02-01 00:42:00 2021-02-01 00:52:00
# 1      2021-02-01 06:29:00 2021-02-01 06:37:00
# 2      2021-02-03 12:27:00 2021-02-03 12:59:00
# 3      2021-02-03 12:42:00 2021-02-03 12:57:00
# 4      2021-02-03 13:26:00 2021-02-03 13:31:00
# ...                    ...                 ...
# 524645 2021-10-31 23:47:00 2021-11-01 00:49:00
# 524646 2021-10-31 23:54:00 2021-10-31 23:59:00
# 524647 2021-10-31 23:59:00 2021-11-01 00:28:00
# 524648 2021-10-31 23:59:00 2021-11-01 00:11:00
# 524649 2021-10-31 23:59:00 2021-11-01 00:29:00
#
#                       start station name start station id   end station name  \
# 0                              City Hall            JC003    Brunswick & 6th
# 1                             Bergen Ave            JC095            Sip Ave
# 2                             Newark Ave            JC032       Morris Canal
# 3                           Morris Canal            JC072       Newport Pkwy
# ...

# %%
file3 = "C:/Users/rvern/Documents/GitHub/tableau/us_counties_covid.csv"
df3 = pd.read_csv(file3)

df3a = df3[df3["county"]=="New York City"]
df3a
# Out:
#              date         county     state  fips   cases   deaths
# 416      3/1/2020  New York City  New York   NaN       1      0.0
# 448      3/2/2020  New York City  New York   NaN       1      0.0
# 482      3/3/2020  New York City  New York   NaN       2      0.0
# 518      3/4/2020  New York City  New York   NaN       2      0.0
# 565      3/5/2020  New York City  New York   NaN       4      0.0
# ...           ...            ...       ...   ...     ...      ...
# 786081  12/1/2020  New York City  New York   NaN  319301  24287.0
# 789327  12/2/2020  New York City  New York   NaN  322501  24297.0
# 792573  12/3/2020  New York City  New York   NaN  325806  24305.0
# 795818  12/4/2020  New York City  New York   NaN  329406  24323.0
# 799064  12/5/2020  New York City  New York   NaN  332633  24346.0
#
# [280 rows x 6 columns]

# %%
df3a['cases_daily'] = df['cases'].diff()
df3a['deaths_daily'] = df['deaths'].diff()
df3a
# Out:
# <ipython-input-201-4e98abbdd0e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3a['cases_daily'] = df['cases'].diff()
# <ipython-input-201-4e98abbdd0e2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3a['deaths_daily'] = df['deaths'].diff()
#              date         county     state  fips   cases   deaths  \
# 416      3/1/2020  New York City  New York   NaN       1      0.0
# 448      3/2/2020  New York City  New York   NaN       1      0.0
# ...

# %%
df1.head()
# Out:
#    tripduration           starttime            stoptime  start station id  \
# 0          1553 2019-12-01 00:07:00 2019-12-01 00:33:00              3681
# 1           416 2019-12-01 00:16:00 2019-12-01 00:23:00              3195
# 2           294 2019-12-01 00:20:00 2019-12-01 00:25:00              3195
# 3            97 2019-12-01 00:21:00 2019-12-01 00:22:00              3202
# 4           286 2019-12-01 00:29:00 2019-12-01 00:34:00              3195
#
#   start station name  start station latitude  start station longitude  \
# 0           Grand St               40.715178               -74.037683
# 1            Sip Ave               40.730897               -74.063913
# 2            Sip Ave               40.730897               -74.063913
# 3       Newport PATH               40.727224               -74.033759
# 4            Sip Ave               40.730897               -74.063913
#
#    end station id  end station name  end station latitude  \
# ...

# %% [markdown]
# df2.columns

# %%
df2.columns
# Out:
# Index(['starttime', 'stoptime', 'start station name', 'start station id',
#        'end station name', 'end station id', 'start station latitude',
#        'start station longitude', 'end station latitude',
#        'end station longitude', 'usertype', 'tripduration'],
#       dtype='object')

# %% [raw]
# df2["usertype"] = df2["usertype"].replace("member","Subscriber", inplace=True)

# %%
df2["usertype"].value_counts()
# Out:
# member    270580
# casual    254070
# Name: usertype, dtype: int64

# %%
frames = [df1,df2]
df4 = pd.concat(frames)
df4
# Out:
#         tripduration           starttime            stoptime start station id  \
# 0             1553.0 2019-12-01 00:07:00 2019-12-01 00:33:00             3681
# 1              416.0 2019-12-01 00:16:00 2019-12-01 00:23:00             3195
# 2              294.0 2019-12-01 00:20:00 2019-12-01 00:25:00             3195
# 3               97.0 2019-12-01 00:21:00 2019-12-01 00:22:00             3202
# 4              286.0 2019-12-01 00:29:00 2019-12-01 00:34:00             3195
# ...              ...                 ...                 ...              ...
# 524645        3720.0 2021-10-31 23:47:00 2021-11-01 00:49:00            JC057
# 524646         300.0 2021-10-31 23:54:00 2021-10-31 23:59:00            HB105
# 524647        1740.0 2021-10-31 23:59:00 2021-11-01 00:28:00            JC102
# 524648         720.0 2021-10-31 23:59:00 2021-11-01 00:11:00            JC095
# 524649        1800.0 2021-10-31 23:59:00 2021-11-01 00:29:00            JC102
#
# ...

# %%
df4["usertype"] = df4["usertype"].str.replace("member","Subscriber")

# %%
df4["usertype"] = df4["usertype"].str.replace("casual","Customer")

# %%
df4
# Out:
#         tripduration           starttime            stoptime start station id  \
# 0             1553.0 2019-12-01 00:07:00 2019-12-01 00:33:00             3681
# 1              416.0 2019-12-01 00:16:00 2019-12-01 00:23:00             3195
# 2              294.0 2019-12-01 00:20:00 2019-12-01 00:25:00             3195
# 3               97.0 2019-12-01 00:21:00 2019-12-01 00:22:00             3202
# 4              286.0 2019-12-01 00:29:00 2019-12-01 00:34:00             3195
# ...              ...                 ...                 ...              ...
# 524645        3720.0 2021-10-31 23:47:00 2021-11-01 00:49:00            JC057
# 524646         300.0 2021-10-31 23:54:00 2021-10-31 23:59:00            HB105
# 524647        1740.0 2021-10-31 23:59:00 2021-11-01 00:28:00            JC102
# 524648         720.0 2021-10-31 23:59:00 2021-11-01 00:11:00            JC095
# 524649        1800.0 2021-10-31 23:59:00 2021-11-01 00:29:00            JC102
#
# ...

# %%
df4.to_csv("C:/Users/rvern/Documents/GitHub/tableau/stationdata_clean.csv",index=False, header=True)
df3a.to_csv("C:/Users/rvern/Documents/GitHub/tableau/covid_newyork.csv",index=False, header=True)

# %%
df4
# Out:
#        tripduration           starttime            stoptime start station id  \
# 0            1553.0 2019-12-01 00:07:00 2019-12-01 00:33:00             3681
# 1             416.0 2019-12-01 00:16:00 2019-12-01 00:23:00             3195
# 2             294.0 2019-12-01 00:20:00 2019-12-01 00:25:00             3195
# 3              97.0 2019-12-01 00:21:00 2019-12-01 00:22:00             3202
# 4             286.0 2019-12-01 00:29:00 2019-12-01 00:34:00             3195
# ...             ...                 ...                 ...              ...
# 21999         180.0 2021-03-31 22:53:00 2021-03-31 22:56:00            JC005
# 22000         300.0 2021-03-31 23:09:00 2021-03-31 23:14:00            JC005
# 22001         300.0 2021-03-31 23:21:00 2021-03-31 23:26:00            JC093
# 22002         180.0 2021-03-31 23:21:00 2021-03-31 23:24:00            JC106
# 22003        1140.0 2021-03-31 23:41:00 2021-04-01 00:00:00            JC011
#
# ...

# %%
df4["startdate"] = pd.to_datetime(df4.starttime, format = '%Y-%m-%d')
df4["startdate"] = df4["startdate"].dt.strftime('%m/%d/%Y')
df4
# Out:
#         tripduration           starttime            stoptime start station id  \
# 0             1553.0 2019-12-01 00:07:00 2019-12-01 00:33:00             3681
# 1              416.0 2019-12-01 00:16:00 2019-12-01 00:23:00             3195
# 2              294.0 2019-12-01 00:20:00 2019-12-01 00:25:00             3195
# 3               97.0 2019-12-01 00:21:00 2019-12-01 00:22:00             3202
# 4              286.0 2019-12-01 00:29:00 2019-12-01 00:34:00             3195
# ...              ...                 ...                 ...              ...
# 524645        3720.0 2021-10-31 23:47:00 2021-11-01 00:49:00            JC057
# 524646         300.0 2021-10-31 23:54:00 2021-10-31 23:59:00            HB105
# 524647        1740.0 2021-10-31 23:59:00 2021-11-01 00:28:00            JC102
# 524648         720.0 2021-10-31 23:59:00 2021-11-01 00:11:00            JC095
# 524649        1800.0 2021-10-31 23:59:00 2021-11-01 00:29:00            JC102
#
# ...

# %%
d5 = df4.groupby(["startdate"])
d5.count().head
# Out:
# <bound method NDFrame.head of             tripduration  starttime  stoptime  start station id  \
# startdate
# 01/01/2020           370        370       370               370
# 01/01/2021           206        206       206               206
# 01/02/2020           892        892       892               892
# 01/02/2021           504        504       504               504
# 01/03/2020           772        772       772               772
# ...                  ...        ...       ...               ...
# 12/29/2020           391        391       391               391
# 12/30/2019           327        327       327               327
# 12/30/2020           326        326       326               326
# 12/31/2019           716        716       716               716
# 12/31/2020           292        292       292               292
#
#             start station name  start station latitude  \
# startdate
# 01/01/2020                 370                     370
# ...

# %%
d6 = d5["end station id"].count()
d7 = pd.DataFrame(d6)
d7.reset_index()
d7
# Out:
#             end station id
# startdate
# 01/01/2020             370
# 01/01/2021             206
# 01/02/2020             892
# 01/02/2021             504
# 01/03/2020             772
# ...                    ...
# 12/29/2020             391
# 12/30/2019             327
# 12/30/2020             326
# 12/31/2019             716
# 12/31/2020             292
#
# [700 rows x 1 columns]

# %%
d7.to_csv("C:/Users/rvern/Documents/GitHub/tableau/station_daygrouped.csv",index=True, header=True)

# %%
file15 = "C:/Users/rvern/Documents/GitHub/tableau/stationdata_clean.csv"
df15 = pd.read_csv(file15)

df15["sum_row"] = 1
df15
# Out:
# C:\Users\rvern\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         tripduration         starttime          stoptime start station id  \
# 0               1553    12/1/2019 0:07    12/1/2019 0:33             3681
# 1                416    12/1/2019 0:16    12/1/2019 0:23             3195
# 2                294    12/1/2019 0:20    12/1/2019 0:25             3195
# 3                 97    12/1/2019 0:21    12/1/2019 0:22             3202
# 4                286    12/1/2019 0:29    12/1/2019 0:34             3195
# ...              ...               ...               ...              ...
# 879348          3720  10/31/2021 23:47    11/1/2021 0:49            JC057
# 879349           300  10/31/2021 23:54  10/31/2021 23:59            HB105
# ...

# %%
d16 = df15.groupby(["start station id","start station latitude","start station longitude"])
d16.count().head
# Out:
# <bound method NDFrame.head of                                                                  tripduration  \
# start station id start station latitude start station longitude
# 3184             40.714145              -74.033552                       7817
# 3185             40.717732              -74.043845                       9333
# 3186             40.719586              -74.043117                      23229
# 3187             40.721124              -74.038051                       8769
# 3191             40.718211              -74.083639                       1564
# ...                                                                       ...
# JC107            40.709198              -74.080843                        268
# JC108            40.706575              -74.086701                         17
#                                         -74.086700                          3
#                                         -74.086701                        641
# ...

# %%
d17 = d16["sum_row"].count()
d18 = pd.DataFrame(d17)
d18.reset_index()
d18
# Out:
#                                                                  sum_row
# start station id start station latitude start station longitude
# 3184             40.714145              -74.033552                  7817
# 3185             40.717732              -74.043845                  9333
# 3186             40.719586              -74.043117                 23229
# 3187             40.721124              -74.038051                  8769
# 3191             40.718211              -74.083639                  1564
# ...                                                                  ...
# JC107            40.709198              -74.080843                   268
# JC108            40.706575              -74.086701                    17
#                                         -74.086700                     3
#                                         -74.086701                   641
# JCSYS            40.709651              -74.068601                     2
#
# [316 rows x 1 columns]

# %%
d18.to_csv("C:/Users/rvern/Documents/GitHub/tableau/station_start_grouped.csv",index=True, header=True)

# %%
d19 = df15.groupby(["end station id","end station latitude","end station longitude"])
d19.count().head
d20 = d19["sum_row"].count()
d21 = pd.DataFrame(d20)
d21.reset_index()
d21
d21.to_csv("C:/Users/rvern/Documents/GitHub/tableau/station_end_grouped.csv",index=True, header=True)
